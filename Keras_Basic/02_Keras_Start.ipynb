# %%
import scipy
import numpy
import matplotlib
import pandas
import sklearn
#import pydot
import h5py

#import theano  # 제거되었다고 오래된 버전이라고 나옴.
import tensorflow
import keras

print('scipy ' + scipy.__version__)
print('numpy ' + numpy.__version__)
print('matplotlib ' + matplotlib.__version__)
print('pandas ' + pandas.__version__)
print('sklearn ' + sklearn.__version__)
#print('pydot ' + pydot.__version__)
print('h5py ' + h5py.__version__)

#print('theano ' + theano.__version__)
print('tensorflow ' + tensorflow.__version__)
print('keras ' + keras.__version__)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-35e665aa5414> in <module>
#       7 import h5py
#       8
# ----> 9 import theano
#      10 import tensorflow
#      11 import keras
#
# /usr/local/lib/python3.6/dist-packages/theano/__init__.py in <module>
#      86
#      87
# ---> 88 from theano.configdefaults import config
#      89 from theano.configparser import change_flags
#      90
#
# /usr/local/lib/python3.6/dist-packages/theano/configdefaults.py in <module>
#     135      "letters, only lower case even if NVIDIA uses capital letters."),
#     136     DeviceParam('cpu', allow_override=False),
# --> 137     in_c_key=False)
#     138
#     139 AddConfigVar(
#
# /usr/local/lib/python3.6/dist-packages/theano/configparser.py in AddConfigVar(name, doc, configparam, root, in_c_key)
#     285         # This allow to filter wrong value from the user.
#     286         if not callable(configparam.default):
# --> 287             configparam.__get__(root, type(root), delete_key=True)
#     288         else:
#     289             # We do not want to evaluate now the default value
#
# /usr/local/lib/python3.6/dist-packages/theano/configparser.py in __get__(self, cls, type_, delete_key)
#     333                 else:
#     334                     val_str = self.default
# --> 335             self.__set__(cls, val_str)
#     336         # print "RVAL", self.val
#     337         return self.val
#
# /usr/local/lib/python3.6/dist-packages/theano/configparser.py in __set__(self, cls, val)
#     344         # print "SETTING PARAM", self.fullname,(cls), val
#     345         if self.filter:
# --> 346             self.val = self.filter(val)
#     347         else:
#     348             self.val = val
#
# /usr/local/lib/python3.6/dist-packages/theano/configdefaults.py in filter(val)
#     114             elif val.startswith('gpu'):
#     115                 raise ValueError(
# --> 116                     'You are tring to use the old GPU back-end. '
#     117                     'It was removed from Theano. Use device=cuda* now. '
#     118                     'See https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29 '
#
# ValueError: You are tring to use the old GPU back-end. It was removed from Theano. Use device=cuda* now. See https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29 for more information.

# %% [markdown]
# ## 딥러닝 기본 모델 구동 확인

# %%
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation

(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
X_train = X_train.reshape(60000, 784).astype('float32') / 255.0
X_test = X_test.reshape(10000, 784).astype('float32') / 255.0
Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)

model = Sequential()
model.add(Dense(units=64, input_dim=28*28, activation='relu'))
model.add(Dense(units=10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
model.fit(X_train, Y_train, epochs=5, batch_size=32)

loss_and_metrics = model.evaluate(X_test, Y_test, batch_size=32)

print('loss_and_metrics : ' + str(loss_and_metrics))
# Out:
# Using TensorFlow backend.
# Epoch 1/5
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.6798 - acc: 0.8237
# Epoch 2/5
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.3477 - acc: 0.9025
# Epoch 3/5
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.3004 - acc: 0.9162
# Epoch 4/5
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.2724 - acc: 0.9240
# Epoch 5/5
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.2507 - acc: 0.9303
# 10000/10000 [==============================] - 0s 31us/step
# loss_and_metrics : [0.23333958752155304, 0.9341]

# %% [markdown]
# ### 딥러닝 모델 시각화

# %% [markdown]
# * 에러 발생 : Failed to import `pydot`. Please install `pydot`. For example with `pip install pydot`.

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import pydot
# %matplotlib inline

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-b7be228d4297> in <module>
# ----> 1 SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir)
#      53     from ..models import Sequential
#      54
# ---> 55     _check_pydot()
#      56     dot = pydot.Dot()
#      57     dot.set('rankdir', rankdir)
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/vis_utils.py in _check_pydot()
#      18     if pydot is None:
#      19         raise ImportError(
# ---> 20             'Failed to import `pydot`. '
#      21             'Please install `pydot`. '
#      22             'For example with `pip install pydot`.')
#
# ImportError: Failed to import `pydot`. Please install `pydot`. For example with `pip install pydot`.

# %% [markdown]
# ## 딥러닝 모델 저장 기능 확인
# * 딥러닝 모델의 구성과 가중치를 저장 및 로드
# * 만약 에러 코드가 mnist_mlp_model.h5'파일 생성

# %%
from keras.models import load_model

model.save('mnist_mlp_model.h5')
model = load_model('mnist_mlp_model.h5')

# %%
# !ls -ltr
# Out:
# total 452
# -rw-r--r-- 1 root root   8478 Jan 10 11:18 01_Keras_Start.ipynb
# -rw-r--r-- 1 root root  16351 Jan 10 11:44 02_Keras_Start.ipynb
# -rwxr-xr-x 1 root root     40 Jan 10 11:47 rubyExample.rb
# -rw-r--r-- 1 root root 428088 Jan 10 11:55 mnist_mlp_model.h5
